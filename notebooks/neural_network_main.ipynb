# %%
import pandas as pd
import numpy as np

# %%
import IPython
js_code = '''
function ClickConnect(){
console.log("Working");
document.querySelector("colab-toolbar-button#connect").click()
}
setInterval(ClickConnect,60000)
'''
display(IPython.display.Javascript(js_code))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/My\ Drive/CURSO/Proyecto/saturdays-cuentos-code/
# Out:
# /content/drive/My Drive/CURSO/Proyecto/saturdays-cuentos-code

# %%
#@markdown #**Installation of libraries**
# @markdown This cell will take a little while because it has to download several libraries

#@markdown ---
 
print("Installing CLIP...")
# !git clone https://github.com/openai/CLIP                 &> /dev/null
 
print("Installing Python Libraries for AI...")
# !git clone https://github.com/CompVis/taming-transformers &> /dev/null
# !pip install transformers                                 &> /dev/null
# !pip install ftfy regex tqdm omegaconf pytorch-lightning  &> /dev/null
# !pip install kornia                                       &> /dev/null
# !pip install einops                                       &> /dev/null
# !pip install wget                                         &> /dev/null
 
print("Installing libraries for metadata management...")
# !pip install stegano                                      &> /dev/null
# !apt install exempi                                       &> /dev/null
# !pip install python-xmp-toolkit                           &> /dev/null
# !pip install imgtag                                       &> /dev/null
# !pip install pillow==7.1.2                                &> /dev/null
 
print("Installing Python libraries for creating videos...")
# !pip install imageio-ffmpeg                               &> /dev/null
# !mkdir steps
# !pip install fpdf
print("Installation completed.")
# Out:
# Installing CLIP...
# Installing Python Libraries for AI...
# Installing libraries for metadata management...
# Installing Python libraries for creating videos...
# mkdir: cannot create directory ‘steps’: File exists
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fpdf in /usr/local/lib/python3.7/dist-packages (1.7.2)
# Installation completed.

# %%
# !python main_tales.py
# Out:
# Reading CSV to generate json config file
# ---------------------------------------------------------------------------
# Building PDF....
# Generating page 0
# Building page...
# Generating page 1
# Building page...
# Generating page 2
# Building page...
# Generating page 3
# Building page...
# Generating page 4
# Building page...
# Generating page 5
# Building page...
# Generating page 6
# Building page...
# Generating page 7
# Building page...
# DONE

# %%
# %ls
# Out:
# CLIP/          image_model.py  progress.png      taming-transformers/
# config.json    main.py         __pycache__/      upleft.PNG
# downleft.PNG   newcap.PNG      requirements.txt  upright.PNG
# downright.PNG  pdf_pages.py    steps/            vqgan_imagenet_f16_16384.yaml
